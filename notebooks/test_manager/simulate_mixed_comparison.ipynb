# %%
# Parameters
artificial_humans = {
    "full": {
        "contribution_model": "data/behavioral_cloning/21_contribution_model_v4/model/architecture_node+edge+rnn__dataset_full.pt",
        "valid_model": "data/behavioral_cloning/22_contribution_valid_model_v4/model/rnn_False__dataset_full.pt",
    }
}
managers = {
    "humanlike": {
        "type": "human",
        "path": "artifacts/behavioral_cloning/23_punishment_autoregressive_v4/model/architecture_node+edge.pt",
        "autoregressive": True,
    },
    "optimal_new": {
        "type": "rl",
        "path": "data/manager/17_exp2_group_payoff_heavy_optimize/model/_manager.pt",
    },
    "optimal_old": {
        "type": "rl",
        "path": "artifacts/manager/17_exp2_group_payoff_heavy_optimize/model/_manager.pt",
    },
}
n_episode_steps = 32
n_episodes = 100
output_dir = "notebooks/test_manager/simulate_mixed/12_b_heavies_mixed"
base_dir = "../../"
basedir = "."

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline


import os
import random
from itertools import count

import numpy as np
import pandas as pd
import seaborn as sns
import torch as th
import sys

# pytorch geometric meta module has changed place
# since the the saving of the training data, this points
# to the new location
import torch_geometric.nn.models.meta as meta_module
sys.modules['torch_geometric.nn.meta'] = meta_module

from aimanager.artificial_humans import GraphNetwork
from aimanager.manager.api_manager import MultiManager
from aimanager.manager.environment import ArtificialHumanEnv
from aimanager.manager.memory import Memory
from aimanager.utils.array_to_df import add_labels, using_multiindex
from aimanager.utils.utils import make_dir

plot_folder = output_dir

make_dir(plot_folder)

managers = {k:{**v, 'model_path': os.path.join(basedir, v['path'])} for k,v in managers.items()}
managers
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# {'humanlike': {'type': 'human',
#   'path': 'artifacts/behavioral_cloning/23_punishment_autoregressive_v4/model/architecture_node+edge.pt',
#   'autoregressive': True,
#   'model_path': '../../artifacts/behavioral_cloning/23_punishment_autoregressive_v4/model/architecture_node+edge.pt'},
#  'optimal_new': {'type': 'rl',
#   'path': 'data/manager/01_rnn_node/model/none.pt',
#   'model_path': '../../data/manager/01_rnn_node/model/none.pt'},
#  'optimal_old': {'type': 'rl',
#   'path': 'artifacts/manager/17_exp2_group_payoff_heavy_optimize/model/_manager.pt',
#   'model_path': '../../artifacts/manager/17_exp2_group_payoff_heavy_optimize/model/_manager.pt'}}

# %%
def mem_to_df(recorder, name):
    columns = ["episode", "participant_code", "round_number"]

    punishments = using_multiindex(
        recorder.memory["punishment"].squeeze(1).numpy(),
        columns=columns,
        value_name="punishment",
    )
    common_good = using_multiindex(
        recorder.memory["common_good"].squeeze(1).numpy(),
        columns=columns,
        value_name="common_good",
    )
    contributions = using_multiindex(
        recorder.memory["contribution"].squeeze(1).numpy(),
        columns=columns,
        value_name="contribution",
    )
    group = using_multiindex(
        recorder.memory["group"].squeeze(1).numpy(), columns=columns, value_name="group"
    )

    df_sim = punishments.merge(common_good).merge(contributions).merge(group)

    df_sim["participant_code"] = (
        df_sim["participant_code"].astype(str) + "_" + df_sim["episode"].astype(str)
    )

    df_sim["run"] = name
    return df_sim


def make_round(contributions, round, groups, episode_group_idx):
    return {
        "contribution": contributions,
        "contribution_valid": [c is not None for c in contributions],
        "punishment_valid": [False] * len(contributions),
        "punishment": [None] * len(contributions),
        "group": groups,
        "round": round,
        "episode_group_idx": episode_group_idx,
    }


def add_punishments(round, punishments):
    return {
        **round,
        "punishment": punishments,
        "punishment_valid": [p is not None for p in punishments],
    }

# %%
device = th.device("cuda")
rec_device = th.device("cpu")

mm = MultiManager(
    managers,
    n_steps=n_episode_steps,
)

# fix bug
for k, man in mm.managers.items():
    if "autoregressive" in managers[k]:
        man.model.autoregressive = managers[k]["autoregressive"]

runs = {
    f"ah {h} managed by {m}": {"groups": [m] * 4, "humans": h}
    for m in managers.keys()
    for h in artificial_humans.keys()
}

dfs = []
for name, run in runs.items():
    print(f"Start run {name}")
    groups = run["groups"]
    n_agents = len(groups)

    hm_path = os.path.join(
        basedir, artificial_humans[run["humans"]]["contribution_model"]
    )
    hmv_path = os.path.join(basedir, artificial_humans[run["humans"]]["valid_model"])

    ah = GraphNetwork.load(hm_path, device=device)
    ah_val = GraphNetwork.load(hmv_path, device=device)
    env = ArtificialHumanEnv(
        artifical_humans=ah,
        artifical_humans_valid=ah_val,
        n_agents=n_agents,
        n_contributions=21,
        n_punishments=31,
        n_rounds=n_episode_steps,
        batch_size=1,
        device=device,
    )
    recorder = Memory(
        n_episodes=n_episodes,
        n_episode_steps=n_episode_steps,
        output_file=None,
        device=rec_device,
    )
    for e in range(n_episodes):
        state = env.reset()
        episode_group_idx = random.randint(0, 1000000)
        rounds = []
        for round_number in count():
            contributions = state["contribution"].squeeze().tolist()
            round = make_round(contributions, round_number, groups, episode_group_idx)
            punishments = mm.get_punishments(rounds + [round])[0]
            round = add_punishments(round, punishments)
            rounds.append(round)
            punishments = th.tensor(punishments, dtype=th.int64, device=device)
            state = env.punish(punishments.unsqueeze(-1).unsqueeze(0))
            recorder.add(
                **{
                    k: v if len(v.shape) == 3 else v.unsqueeze(-1)
                    for k, v in state.items()
                },
                episode_step=round_number,
            )
            state, reward, done = env.step()
            if done:
                break
        recorder.next_episode(e)
    dfs.append(mem_to_df(recorder, name=name))
# Out:
# Start run ah full managed by humanlike
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 56
#      54 contributions = state["contribution"].squeeze().tolist()
#      55 round = make_round(contributions, round_number, groups, episode_group_idx)
# ---> 56 punishments = mm.get_punishments(rounds + [round])[0]
#      57 round = add_punishments(round, punishments)
#      58 rounds.append(round)
#
# File /raven/u/certuer/algorithmic-institutions/src/aimanager/manager/api_manager.py:176, in MultiManager.get_punishments(self, rounds)
#     165 def get_punishments(self, rounds):
#     166     # we use the batch dimension to seperate the different groups
#     167     # we mask contributions and punishments corresponding to the groups
#     168     # the batch size corresponds to the number of models
#     169     # the data for both models is identical in principal, we compute them
#     170     # seperately as the models might use different default values
#     171     data = {
#     172         k: create_data(rounds, self.groups, m.default_values)
#     173         for k, m in self.managers.items()
#     174     }
# --> 176     punishment = {k: m.get_punishments(data[k]) for k, m in self.managers.items()}
#     178     # we select from the model responds only those matching the right group
#     179     # this is the same for all models and independent of the actual model of
#     180     # the group
#     181     # we also select the last punishment in the round dimension
#     182     group = rounds[-1]["group"]
#
# File /raven/u/certuer/algorithmic-institutions/src/aimanager/manager/api_manager.py:176, in <dictcomp>(.0)
#     165 def get_punishments(self, rounds):
#     166     # we use the batch dimension to seperate the different groups
#     167     # we mask contributions and punishments corresponding to the groups
#     168     # the batch size corresponds to the number of models
#     169     # the data for both models is identical in principal, we compute them
#     170     # seperately as the models might use different default values
#     171     data = {
#     172         k: create_data(rounds, self.groups, m.default_values)
#     173         for k, m in self.managers.items()
#     174     }
# --> 176     punishment = {k: m.get_punishments(data[k]) for k, m in self.managers.items()}
#     178     # we select from the model responds only those matching the right group
#     179     # this is the same for all models and independent of the actual model of
#     180     # the group
#     181     # we also select the last punishment in the round dimension
#     182     group = rounds[-1]["group"]
#
# File /raven/u/certuer/algorithmic-institutions/src/aimanager/manager/api_manager.py:129, in RLManager.get_punishments(self, data)
#     125 def get_punishments(self, data):
#     126     # the round number only enteres the bias and hence does not effect the
#     127     # output, set to zero to allow for larger rollout length
#     128     data["round_number"] = th.zeros_like(data["round_number"])
# --> 129     pred = self.model.predict(data, sample=False)[0]
#     130     return pred
#
# File /raven/u/certuer/algorithmic-institutions/src/aimanager/generic/graph.py:355, in GraphNetwork.predict(self, *args, **kwargs)
#     353     return self.predict_autoreg(*args, **kwargs)
#     354 else:
# --> 355     return self.predict_independent(*args, **kwargs)
#
# File /raven/u/certuer/algorithmic-institutions/src/aimanager/generic/graph.py:287, in GraphNetwork.predict_independent(self, data, sample, reset_rnn, edge_index)
#     283     edge_index = self.create_fully_connected(n_nodes, n_groups=n_batch)
#     284 encoded = self.encode(
#     285     data, y_encode=False, edge_index=edge_index, device=self.device
#     286 )
# --> 287 predict = self.predict_encoded(encoded, sample=sample, reset_rnn=reset_rnn)
#     288 predict = tuple(t.reshape((n_batch, n_nodes, *t.shape[1:])) for t in predict)
#     289 return predict
#
# File /raven/u/certuer/algorithmic-institutions/src/aimanager/generic/graph.py:275, in GraphNetwork.predict_encoded(self, data, sample, reset_rnn)
#     273 def predict_encoded(self, data, sample=True, reset_rnn=True):
#     274     self.eval()
# --> 275     y_logit = self(data, reset_rnn)
#     276     y_pred_proba = th.nn.functional.softmax(y_logit, dim=-1)
#     277     y_pred = self.y_encoder.decode(y_pred_proba, sample)
#
# File ~/algorithmic-institutions/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /raven/u/certuer/algorithmic-institutions/src/aimanager/generic/graph.py:224, in GraphNetwork.forward(self, data, reset_rnn)
#     222 u = data["u"]
#     223 batch = data["batch"]
# --> 224 x, _, u = self.op1(x, edge_index, edge_attr, u, batch)
#     225 if self.rnn_n is not None:
#     226     x, self.rnn_n_h0 = self.rnn_n(x, None if reset_rnn else self.rnn_n_h0)
#
# File ~/algorithmic-institutions/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/algorithmic-institutions/.venv/lib/python3.9/site-packages/torch_geometric/nn/models/meta.py:147, in MetaLayer.forward(self, x, edge_index, edge_attr, u, batch)
#     143     edge_attr = self.edge_model(x[row], x[col], edge_attr, u,
#     144                                 batch if batch is None else batch[row])
#     146 if self.node_model is not None:
# --> 147     x = self.node_model(x, edge_index, edge_attr, u, batch)
#     149 if self.global_model is not None:
#     150     u = self.global_model(x, edge_index, edge_attr, u, batch)
#
# File ~/algorithmic-institutions/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1110, in Module._call_impl(self, *input, **kwargs)
#    1106 # If we don't have any hooks, we want to skip the rest of the logic in
#    1107 # this function, and just call forward.
#    1108 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110     return forward_call(*input, **kwargs)
#    1111 # Do not call functions when jit is used
#    1112 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /raven/u/certuer/algorithmic-institutions/src/aimanager/generic/graph.py:47, in NodeModel.forward(self, x, edge_index, edge_attr, u, batch)
#      40 def forward(self, x, edge_index, edge_attr, u, batch):
#      41     # x: [N, F_x], where N is the number of nodes.
#      42     # edge_index: [2, E] with max entry N - 1.
#      43     # edge_attr: [E, F_e]
#      44     # u: [B, F_u]
#      45     # batch: [N] with max entry B - 1.
#      46     row, col = edge_index
# ---> 47     out = scatter_mean(edge_attr, col, dim=0, dim_size=x.size(0))
#      48     out = th.cat([x, out, u[batch]], dim=-1)
#      49     out = self.node_mlp(out)
#
# File ~/algorithmic-institutions/.venv/lib/python3.9/site-packages/torch_scatter/scatter.py:41, in scatter_mean(src, index, dim, out, dim_size)
#      38 def scatter_mean(src: torch.Tensor, index: torch.Tensor, dim: int = -1,
#      39                  out: Optional[torch.Tensor] = None,
#      40                  dim_size: Optional[int] = None) -> torch.Tensor:
# ---> 41     out = scatter_sum(src, index, dim, out, dim_size)
#      42     dim_size = out.size(dim)
#      44     index_dim = dim
#
# File ~/algorithmic-institutions/.venv/lib/python3.9/site-packages/torch_scatter/scatter.py:20, in scatter_sum(src, index, dim, out, dim_size)
#      18     else:
#      19         size[dim] = int(index.max()) + 1
# ---> 20     out = torch.zeros(size, dtype=src.dtype, device=src.device)
#      21     return out.scatter_add_(dim, index, src)
#      22 else:
#
# KeyboardInterrupt:

# %%
data_file = "experiments/pilot_random1_player_round_slim.csv"
data_file = os.path.join(basedir, data_file)

df_pilot = pd.read_csv(data_file)

experiment_name_map = {
    "trail_rounds_2": "pilot human manager",
    "random_1": "pilot rule based manager",
}

df_pilot["run"] = df_pilot["experiment_name"].map(experiment_name_map)
df_pilot["common_good"] = df_pilot["common_good"] / 4
df_pilot = df_pilot[
    [
        "round_number",
        "common_good",
        "contribution",
        "participant_code",
        "punishment",
        "run",
        "global_group_id",
    ]
]

df_pilot["episode"] = df_pilot["global_group_id"]

df = pd.concat([*dfs, df_pilot]).reset_index(drop=True)

df["episode"] = df["run"] + "__" + df["episode"].astype(str)

dfm = df.melt(
    id_vars=["episode", "round_number", "participant_code", "run"],
    value_vars=["punishment", "contribution", "common_good"],
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 27
#      13 df_pilot = df_pilot[
#      14     [
#      15         "round_number",
#    (...)
#      22     ]
#      23 ]
#      25 df_pilot["episode"] = df_pilot["global_group_id"]
# ---> 27 df = pd.concat([*dfs, df_pilot]).reset_index(drop=True)
#      29 df["episode"] = df["run"] + "__" + df["episode"].astype(str)
#      31 dfm = df.melt(
#      32     id_vars=["episode", "round_number", "participant_code", "run"],
#      33     value_vars=["punishment", "contribution", "common_good"],
#      34 )
#
# NameError: name 'dfs' is not defined

# %%
w = dfm["run"].isin(
    [
        "ah full managed by optimal_old",
        "ah full managed by optimal_new",
        "ah full managed by humanlike",
        # 'pilot human manager',
        # 'pilot rule based manager',
    ]
)

dfg = dfm[w].copy()
dfg["run"] = dfg["run"].map(
    {
        "ah full managed by optimal_old": "optimal manager (old)",
        "ah full managed by optimal_new": "optimal manager (new)",
        "ah full managed by humanlike": "human like manager",
    }
)


g = sns.relplot(
    data=dfg,
    x="round_number",
    y="value",
    col="variable",
    hue="run",
    kind="line",
    facet_kws={"sharey": False, "sharex": True},
    height=3,
    aspect=1,
)


# Set y-axis limits to start at 0 for all plots
g.set(ylim=(0, None))

g.savefig(os.path.join(plot_folder, "comparison_manager.jpg"))

# %%
w = dfm["run"].isin(
    [
        "ah human managed managed by optimal_old",
        "ah human managed managed by optimal_new",
        "ah human managed managed by humanlike",
        "pilot human manager",
        # 'pilot rule based manager',
    ]
)

dfg = dfm[w].copy()
dfg["run"] = dfg["run"].map(
    {
        "ah human managed managed by optimal_old": "optimal manager (old) *",
        "ah human managed managed by optimal_new": "optimal manager (new) *",
        "ah human managed managed by humanlike": "human like manager *",
        "pilot human manager": "pilot",
        "pilot rule based manager": "pilot rule based manager",
    }
)


g = sns.relplot(
    data=dfg,
    x="round_number",
    y="value",
    col="variable",
    hue="run",
    kind="line",
    facet_kws={"sharey": False, "sharex": True},
    height=3,
    aspect=1,
)

# Set y-axis limits to start at 0 for all plots
g.set(ylim=(0, None))

g.savefig(os.path.join(plot_folder, "comparison_pilot.jpg"))

# %%
try:
    import matplotlib.pyplot as plt
    from statannotations.Annotator import Annotator

    order = [
        "ah human managed managed by humanlike",
        "ah all managed by humanlike",
        "pilot human manager",
    ]

    w = (
        (dfm["round_number"] < 8)
        & (dfm["variable"] == "common_good")
        & (dfm["run"].isin(order))
    )

    dfg = (
        dfm[w]
        .groupby(["participant_code", "run", "variable"])["value"]
        .mean()
        .reset_index()
    )

    pairs = [[order[0], order[2]], [order[1], order[2]]]

    plt.figure(figsize=(12, 4))

    ax = sns.barplot(data=dfg, order=order, x="run", y="value")

    annotator = Annotator(ax, pairs, data=dfg, x="run", y="value", order=order)
    annotator.configure(test="Mann-Whitney", text_format="simple", loc="inside")
    annotator.apply_and_annotate()

    plt.savefig(os.path.join(plot_folder, "comparison_pilot_bar.jpg"))
except:
    pass

# %%
df["contribution"] = df["contribution"].astype(int)


w = df["run"].isin(
    [
        "ah full managed by optimal_old",
        "ah full managed by optimal_new",   
        "ah full managed by humanlike",
        "pilot human manager",
        "pilot rule based manager",
    ]
)

dfs = df[w].copy()
dfs["run"] = dfs["run"].map(
    {
        "ah full managed by optimal_old": "optimal manager (old)",
        "ah full managed by optimal_new": "optimal manager (new)",
        "ah full managed by humanlike": "human like manager",
        "pilot human manager": "pilot (human manager)",
        "pilot rule based manager": "pilot (rule manager)",
    }
)


g = sns.catplot(
    data=dfs,
    x="contribution",
    y="punishment",
    hue="run",
    kind="point",
    height=3,
    aspect=2.5,
)

g.savefig(os.path.join(plot_folder, "comparison_pilot_policy.jpg"))

# %%
df["contribution"] = df["contribution"].astype(int)

w = df["run"].isin(
    [
        "ah full managed by optimal_old",
        "ah full managed by optimal_new",
        "ah full managed by humanlike",
        # 'pilot human manager',
        # 'pilot rule based manager',
    ]
)

dfs = df[w].copy()
dfs["run"] = dfs["run"].map(
    {
        "ah full managed by optimal_old": "optimal manager (old)",
        "ah full managed by optimal_new": "optimal manager (new)",
        "ah full managed by humanlike": "human like manager",
        "pilot human manager": "pilot (human manager)",
        "pilot rule based manager": "pilot (rule manager)",
    }
)


g = sns.catplot(
    data=dfs,
    x="contribution",
    y="punishment",
    hue="run",
    kind="boxen",
    height=3,
    aspect=2.5,
)

g.savefig(os.path.join(plot_folder, "comparison_pilot_policy_box.jpg"))

# %%
df["contribution"] = df["contribution"].astype(int)

w = (
    df["run"].isin(
        [
            "ah human managed managed by humanlike",
            "pilot human manager",
        ]
    )
    & (df["round_number"] == 0)
    & (df["contribution"] != 20)
)

dfs = df[w].copy()


dfs["run"] = dfs["run"].map(
    {
        "ah human managed managed by humanlike": "human like manager",
        "pilot human manager": "pilot (human manager)",
    }
)

merge_on = ["run", "episode", "round_number"]
keep = ["punishment", "contribution", "participant_code"]

dfm = pd.merge(left=dfs[merge_on + keep], right=dfs[merge_on + keep], on=merge_on)
dfm = dfm[dfm["participant_code_x"] != dfm["participant_code_y"]]
dfm["contribution_same"] = dfm["contribution_x"] == dfm["contribution_y"]
dfm["punishment_same"] = dfm["punishment_x"] == dfm["punishment_y"]
dfm["punishment_diff"] = np.abs(dfm["punishment_x"] - dfm["punishment_y"])


x, y = (
    "run",
    "punishment_same",
)

w = dfm["contribution_same"]

y_name = "percent"

(
    (dfm[w].groupby(x)[y].mean().mul(100).rename(y_name))
    .reset_index()
    .pipe((sns.catplot, "data"), x=x, y=y_name, kind="bar", height=3, aspect=4)
)

# set title
plt.title("First round punishment agreement (contribution same)")
plt.savefig(os.path.join(plot_folder, "first_round_punishment_agreement.jpg"))
plt.show()

# %%
x, y = (
    "run",
    "punishment_diff",
)

w = dfm["contribution_same"]

y_name = "count"

(
    (dfm[w].groupby(x)[y].value_counts(normalize=True).rename(y_name))
    .reset_index()
    .pipe((sns.catplot, "data"), x=y, y=y_name, hue=x, kind="bar", height=3, aspect=4)
)

plt.title("First round absolute punishment difference (contribution same)")
plt.savefig(os.path.join(plot_folder, "first_round_punishment_difference.jpg"))
plt.show()

# %%
dfm = df.melt(
    id_vars=["episode", "round_number", "participant_code", "run"],
    value_vars=["punishment", "contribution", "common_good"],
)

# w = ((dfm['round_number'] == 0) & (dfm['variable'] == 'contribution'))

dfs = dfm.groupby(["run", "round_number", "variable"])["value"].mean().reset_index()

dfs = dfs.sort_values(["variable", "round_number", "run"])

dfs.to_csv(os.path.join(plot_folder, "aggregates.csv"), index=False)
